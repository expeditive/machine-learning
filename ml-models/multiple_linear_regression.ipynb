# %% [markdown]
# <a href="https://colab.research.google.com/github/expeditive/machine-learning/blob/main/ml-models/multiple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from sklearn.datasets import load_diabetes

# %%
x,y = load_diabetes(return_X_y=True)

# %%
x
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
x.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %% [markdown]
# Using sklearns Linear regression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=2)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
red = LinearRegression()

# %%
red.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = red.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
red.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
red.intercept_
# Out:
# np.float64(151.88331005254167)

# %% [markdown]
# **Making my own Linear Regression Class**

# %%
class MeraLR():

  def __init__(self):
    self.coef_=None
    self.intercept_=None

  def fit(self,x_train,y_train):

    #adding first column with all values 1
    x_train = np.insert(x_train,0,1,axis=1)

    #calculating the coeff matrix
    betas = np.linalg.inv(np.dot(x_train.T,x_train)).dot(x_train.T).dot(y_train)
    self.intercept_= betas[0]
    self.coef_ = betas[1:]

  def predict(self,y_test):
    y_pred = np.dot(x_test, self.coef_) + self.intercept_
    return y_pred

# %%
lr = MeraLR()

# %%
lr.fit(x_train,y_train)

# %%
y_res = lr.predict(x_train)

# %%
r2_score(y_test,y_res)
# Out:
# 0.43993386615689634
